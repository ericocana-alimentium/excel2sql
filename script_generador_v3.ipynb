# %% [markdown]
# ##### Importing the libraries

# %%
import pandas as pd
import warnings
import datetime
import os
import glob
import re

# %% [markdown]
# Ignoring warnings for cleaner output

# %%
warnings.simplefilter(action='ignore', category=UserWarning) # Ignorar warnings

# %%
# file_path = 'excels\Configuracion-WFL-Inicial-v2.xlsx'
# df = pd.read_excel(file_path, index_col=None)
# df.head(3).to_markdown()

# %%
hora_inicio = datetime.datetime.now()
#print(f"Hora de inicio: {hora_inicio.strftime('%H:%M:%S')}")

# %% [markdown]
# ##### Obtener los excels de la carpeta

# %%
# 3. Obtener la ruta del directorio del script y listar todos los archivos Excel en la carpeta
script_path = "excels"
ruta_carpeta_excel = os.path.join(script_path)
archivos_excel = glob.glob(ruta_carpeta_excel + "/*.xlsx")

# %% [markdown]
# Extraer y almacenar solo los nombres de los archivos con y sin extension para posteriormente usarlos y evitar repetir codigo

# %%
archivos_excel_basename = []
nombres_sin_extension = []


for archivo_excel in archivos_excel:
    # Primero, obtener solo el nombre del archivo con extensión usando os.path.basename
    nombre_archivo_con_extension = os.path.basename(archivo_excel)
    archivos_excel_basename.append(nombre_archivo_con_extension)
    # print(nombre_archivo_con_extension)
    # Luego, quitar la extensión para obtener solo el nombre del archivo
    nombre_archivo_sin_extension = os.path.splitext(nombre_archivo_con_extension)[0]
    nombres_sin_extension.append(nombre_archivo_sin_extension)

# %% [markdown]
# ### Función `prepararCabecera`
#
# La función `prepararCabecera` tiene como objetivo generar una cabecera personalizada para un archivo SQL basándose en la entrada del usuario. Aquí está el desglose de su funcionalidad:
#
# #### Proceso
#
# 1. **Inicialización del Link de la Tarea**: La función comienza con un link base para una tarea (`link_tarea`) predefinido, dirigido a un recurso específico en `ClickUp`.
#
# 2. **Entrada de Datos del Usuario**:
#    - `input_tarea`: Se solicita al usuario que introduzca un identificador único de tarea (ejemplo: `PROCLI-3948`). Este identificador se anexa al `link_tarea`.
#    - `descripcion`: Se pide al usuario que introduzca la descripción de la tarea.
#    - `autor`: Se solicita el nombre del autor o autores de la tarea.
#    - `fecha_creacion`: Se registra automáticamente la fecha actual en formato `AAAA-MM-DD` utilizando `hora_inicio.strftime('%Y-%m-%d')`.
#
# 3. **Extracción del Código de Tarea**: Utiliza una expresión regular para extraer el número después del guion en `input_tarea`. Si el formato es incorrecto, se notifica al usuario.
#
# 4. **Generación de la Cabecera SQL**: Crea una cabecera detallada para el archivo SQL que incluye:
#    - Tipos de cambios (EST, DAT, QRY).
#    - Detalles de la tarea como el link, descripción, autor, fechas de creación y despliegue (desarrollo, pre-producción, producción).
#
# #### Salida
#
# - Devuelve una tupla que contiene la `cabecera_sql` generada y el `codigo_tarea` extraído. (Si `codigo_tarea` no es correcto devuelve `None`)
#
# #### Consideraciones Adicionales
#
# - La función no valida directamente el formato de entrada del usuario excepto en la extracción del código de tarea.
# - Las fechas de despliegue (desarrollo, pre-producción, producción) se inicializan como cadenas vacías y no se modifican dentro de la función.
# - La cabecera SQL generada está formateada para ser insertada directamente en un archivo SQL, con detalles claros y estructurados para facilitar la comprensión del contexto de las modificaciones realizadas.

# %%
# Definir los detalles de la tarea y pedirlos al usuario
def prepararCabecera():
    link_tarea = "https://app.clickup.com/t/36671967/"
    input_tarea = input("Introduce la parte del link de la tarea: (ej: PROCLI-3948)")
    link_tarea += input_tarea
    codigo_tarea = re.search(r'\d+', link_tarea).group(0)
    descripcion = input("Introduce la descripción: ")
    autor = input("Introduce el nombre del autor/es: ")
    fecha_creacion = hora_inicio.strftime('%Y-%m-%d')  # Formato: AAAA-MM-DD
    fecha_despliegue_desarrollo = ""
    fecha_despliegue_preproduccion = ""
    fecha_despliegue_produccion = ""

    # Extraer el número después del guion
    codigo_tarea = re.search(r'-(\d+)', input_tarea)
    if codigo_tarea:
        codigo_tarea = codigo_tarea.group(1)
    else:
        print("Formato de tarea incorrecto. Asegúrate de incluir un guion '-' seguido por números.")

    # Generar la cabecera del archivo SQL
    cabecera_sql = f"""
    /*
    * (EST): Estructura. 
    * (DAT): Modificación Datos.
    * (QRY): Consultas.
    */
    -------------------------------------------------------------------------------------
    /*
    * LINK TAREA: {link_tarea}
    * DESCRIPCIÓN: {descripcion}
    * 
    *
    * AUTOR: {autor}
    * FECHA CREACIÓN: {fecha_creacion}
    * FECHA DESPLIEGUE DESARROLLO: {fecha_despliegue_desarrollo}
    * FECHA DESPLIEGUE PRE-PRODUCCIÓN: {fecha_despliegue_preproduccion}
    * FECHA DESPLIEGUE PRODUCCIÓN: {fecha_despliegue_produccion}
    */
    -------------------------------------------------------------------------------------
    ---
    -------------------------------------------------
    --- 
    -------------------------------------------------
    BEGIN TRAN
    """
    #print(cabecera_sql)
    return cabecera_sql, codigo_tarea

# %% [markdown]
# ### Proceso de Generación de Scripts SQL desde Archivos Excel
#
# Este script que parte del script de Nico (**script-generador.ps1**), automatiza la generación de scripts SQL a partir de datos extraídos de archivos Excel. Aquí está el desglose de su funcionalidad:
#
# #### Inicialización de Contadores y Listas
#
# - `contador_lineas_totales = 0`: Inicia un contador para el total de líneas de SQL generadas.
# - `contador = 1`: Un contador para llevar la cuenta de los scripts generados.
#
# #### Procesamiento de Archivos Excel
#
# - **Recorrido por Archivos Excel**: El script itera sobre cada archivo en la lista `archivos_excel`.
#   - Se abre cada archivo Excel usando `pandas.ExcelFile`.
#   - Se llama a la función `prepararCabecera` para obtener la cabecera SQL y el código de tarea.
#
# - **Inicialización de Contenido SQL**: Se prepara una variable `contenido_columna` para acumular el contenido SQL.
#
# - **Recorrido por Hojas de Excel**:
#   - Se itera sobre cada hoja del archivo Excel.
#   - Se lee cada hoja en un DataFrame de pandas.
#   - Si la hoja tiene más de 18 columnas, se selecciona la columna 19 (columna "S").
#
# - **Procesamiento de Datos de Columna**:
#   - Se busca por sentencias `DECLARE` y se extraen los nombres de las variables.
#   - Se realizan varias transformaciones en los datos de la columna para adecuarlos a la sintaxis SQL (por ejemplo, reemplazo de ciertos caracteres y ajuste de cadenas).
#
# - **Inserción de Sentencias `GO` y `DECLARE`**: Cada 45 líneas, se inserta una sentencia `GO` y se redeclaran las variables encontradas.
#
# - **Finalización del Contenido SQL**: Se añade una sentencia `GO` y `commit` al final del contenido.
#
# #### Generación de Archivos SQL
#
# - Se genera un nombre para el archivo SQL usando la fecha actual, el código de tarea y el contador de scripts.
# - Se verifica si el archivo ya existe; si no, se crea.
# - Se escribe el contenido SQL en el archivo.
#
# #### Finalización
#
# - Se incrementa el contador para el siguiente archivo.
# - Al finalizar el procesamiento de todos los archivos Excel, se imprime un mensaje de finalización.
#
# #### Consideraciones Adicionales
#
# - **¡IMPORTANTE: El script no maneja errores de formato en los archivos Excel, por lo que es importante asegurarse de que los archivos cumplan con los requisitos de formato antes de ejecutar el script!**
# - La funcionalidad está altamente enfocada en la estructura específica de los archivos Excel y los requisitos de formato SQL, lo que lo hace útil en escenarios donde esta estructura y requisitos son consistentes.
# - Muestra por pantalla las hojas que no tienen columna S, para que el usuario pueda verificar si es un error o no.
# - La idea es que poco a poco se vaya mejorando para que sea más eficiente y robusto.
#
#
# Este script es una herramienta valiosa para automatizar la tediosa tarea de convertir datos de Excel en scripts SQL, ahorrando tiempo y reduciendo la posibilidad de errores manuales.

# %%
contador_lineas_totales = 0
contador = 1
nombresSQL = []

# Recorrer cada archivo Excel en la lista
for archivo_excel in archivos_excel:
    print(f"Abriendo el archivo {archivo_excel}...")
    workbook = pd.ExcelFile(os.path.join(archivo_excel))

    print(f"Pidiendo datos del archivo Excel: {os.path.basename(archivo_excel)}")

    datos = prepararCabecera()

    cabecera_sql = datos[0]
    codigo_tarea = datos[1]

    # Inicializar el contenido que se escribirá en el archivo SQL
    contenido_columna = "" 
    
    # Añadir la cabecera SQL al contenido
    contenido_columna += cabecera_sql

    # Recorrer cada hoja en el libro Excel
    for sheet_name in workbook.sheet_names:
        #print(f"Hoja: {sheet_name}")
        # Leer la hoja actual en un DataFrame
        df = pd.read_excel(workbook, sheet_name=sheet_name)

        valores_a_usar = []

        # Iteramos a través de cada fila del DataFrame
        for index, row in df.iterrows():
            # Obtenemos los valores de las columnas 'U' y 'W' por índice
            valor_u = row.iloc[19] if len(row) > 19 else None
            valor_w = row.iloc[21] if len(row) > 21 else None
            valor_y = row.iloc[24] if len(row) > 24 else None  # Columna "Y"

            valor_a_usar = None
            
            # Chequeamos primero si 'W' comienza con "UPDATE"
            if valor_w and str(valor_w).strip().lower().startswith("update"):
                valor_a_usar = valor_w
            # Si no, chequeamos si 'U' comienza con "INSERT"
            elif valor_u and str(valor_u).strip().lower().startswith("insert"):
                valor_a_usar = valor_u

             # Si ni "W" es "UPDATE" ni "U" es "INSERT", verificamos "Y" para "DELETE"
            elif valor_y and str(valor_y).strip().lower().startswith("delete"):
                valor_a_usar = valor_y
            else:
                 None
    
         
            if valor_a_usar:
                valores_a_usar.append(valor_a_usar)
            else:
                print(f"Hoja {sheet_name}: fila {index + 1}: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.")
        # Array para almacenar las sentencias DECLARE
        declares = []
        
        # Agregar el nombre de la tabla al contenido
        contenido_columna += f"---Tabla: {sheet_name}\n"
        
        for valor in valores_a_usar:
            if 'DECLARE' in str(valor):
            # Extraer el nombre de la variable y almacenarlo
                nombre_variable = re.search(r'(?<=DECLARE\s@)\w+', valor) # Guardamos el nombre de la variable por si en un futuro queremos hacer algo con ella
                if nombre_variable:
                    declares.append(nombre_variable.group())
            if len(str(valor)) > 70 or 'DECLARE' in str(valor):
                
                valor = str(valor).replace("''", "NULL")
                valor = valor.replace("'NULL'", "NULL")
                valor = valor.replace("%%", "''")
                valor = valor.replace("$$", "\n")
                valor = re.sub(r"(\w)'(\w)", r"\1''\2", valor)

                contenido_columna += valor + "\n"
                contador_lineas_totales += 1

                if contador_lineas_totales % 45 == 0:
                    contenido_columna += "GO\n"
                    for variable in declares:
                        contenido_columna += f"DECLARE @{variable} AS INT\nSET @{variable} = 0\n"
                    declares.clear()  # Limpiar el array para el siguiente lote

    contenido_columna += "GO\ncommit\n"
    print(f"Contador de scripts generados: {contador}")

    nombre_archivo_salida = f"{hora_inicio.strftime('%Y%m%d')}-{codigo_tarea}-00{contador}-DAT-{nombres_sin_extension[contador-1]}.sql"

    nombresSQL.append(nombre_archivo_salida)   


    ruta_archivo_salida = os.path.join(f"sql\{nombre_archivo_salida}")

    if os.path.exists(ruta_archivo_salida):
        print(f"El archivo {nombre_archivo_salida} ya existe. Se sobreescribirá.")
    else:
        os.makedirs(os.path.dirname(ruta_archivo_salida), exist_ok=True)
        
        with open(ruta_archivo_salida, "w") as archivo_salida:
            archivo_salida.write(contenido_columna)
            
        print (f"Archivo {nombre_archivo_salida} generado con éxito")


    
    print(f"Cerramos el archivo {archivo_excel}")
    # print("¡Recuerda borrar los archivos Excel que no necesites!")
    contador += 1

print("FIN")
# Out:
# Abriendo el archivo excels\Configuracion-WFL-Inicial-v4 solo modificaciones.xlsx...
# Pidiendo datos del archivo Excel: Configuracion-WFL-Inicial-v4 solo modificaciones.xlsx
# Formato de tarea incorrecto. Asegúrate de incluir un guion '-' seguido por números.
# Hoja 00.DatosInicialesCliente: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 2: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 3: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 4: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 5: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 6: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 7: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 8: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 9: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 10: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 11: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 12: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 13: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 14: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 15: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 16: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 17: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 18: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 19: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 20: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 21: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 22: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 23: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 24: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 25: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 26: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 27: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 00.DatosInicialesCliente: fila 28: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 10.WorkFlowAgente: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 10.WorkFlowAgente: fila 2: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 11.ConfiguracionModulo: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 20.Roles: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 21.Pasos: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 22.PoliticaAccesoModulo: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 22.PoliticaAccesoModulo: fila 2: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 22.PoliticaAccesoModulo: fila 3: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 23.RolUsuarioEnWorkFlow: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 23.RolUsuarioEnWorkFlow: fila 2: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 24.AsignacionRolPaso: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 24.AsignacionRolPaso: fila 2: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 26.ContactosModulo: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 26.ContactosModulo: fila 2: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 26.ContactosModulo: fila 3: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 26.ContactosModulo: fila 4: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 26.ContactosModulo: fila 5: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 26.ContactosModulo: fila 6: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 26.ContactosModulo: fila 7: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 26.ContactosModulo: fila 8: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 30.Atributos: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 30.Atributos: fila 6: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 30.Atributos: fila 7: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 30.Atributos: fila 8: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 30.Atributos: fila 9: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 30.Atributos: fila 10: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 30.Atributos: fila 11: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 31.AtributosWFL: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 31.AtributosWFL: fila 3: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 31.AtributosWFL: fila 4: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 31.AtributosWFL: fila 5: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 31.AtributosWFL: fila 6: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 31.AtributosWFL: fila 7: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 31.AtributosWFL: fila 8: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 31.AtributosWFL: fila 9: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 31.AtributosWFL: fila 10: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 31.AtributosWFL: fila 11: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 32.ValoresCodificados: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 33.ValorCodificadoWFL: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 33.ValorCodificadoWFL: fila 2: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 33.ValorCodificadoWFL: fila 3: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 33.ValorCodificadoWFL: fila 4: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 34.AtributosCondicionados: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 34.AtributosCondicionados: fila 2: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 34.AtributosCondicionados: fila 3: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 34.AtributosCondicionados: fila 4: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 34.AtributosCondicionados: fila 5: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 35.TraduccionesEntidades: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 36.TraduccionesAtributos: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 36.TraduccionesAtributos: fila 2: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 36.TraduccionesAtributos: fila 3: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 36.TraduccionesAtributos: fila 4: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 36.TraduccionesAtributos: fila 5: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 36.TraduccionesAtributos: fila 6: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 36.TraduccionesAtributos: fila 7: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 36.TraduccionesAtributos: fila 8: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 36.TraduccionesAtributos: fila 9: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 36.TraduccionesAtributos: fila 10: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 36.TraduccionesAtributos: fila 11: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 37.TraduccionesValoresCodificad: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 40.EntidadesNuevas: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 41.Atributos: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 42.ValoresCodificados: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 43.AtributosFT: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 44.ValoresCodificadosFT: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 45.AtributosCondicionados: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 46.TraduccionesEntidades: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 1: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 2: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 3: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 4: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 5: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 6: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 7: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 8: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 9: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 10: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 11: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 12: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 13: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 14: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 15: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 16: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 17: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 18: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 19: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 20: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 21: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 22: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 23: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 24: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 25: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 26: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 27: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 28: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 29: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 30: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 31: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 32: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 33: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 34: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 35: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 36: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 37: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 38: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 39: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 40: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 41: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 42: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 43: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 44: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 45: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 46: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 47: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 48: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 49: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 50: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 51: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 52: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 53: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 54: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 55: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 56: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 57: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 58: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 59: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 60: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 61: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 62: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 63: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 64: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 65: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 66: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 67: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 68: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 69: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 70: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 71: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 72: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 73: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 74: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 75: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 76: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 77: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 78: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 79: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 80: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 81: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 82: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 83: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 84: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 85: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 86: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 87: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 88: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 89: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 90: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 91: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 92: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 93: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 94: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 95: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 96: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 97: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 98: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 99: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 100: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 101: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 102: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 103: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 104: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 105: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 106: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 107: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 108: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 109: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 110: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 111: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 112: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 113: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 114: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 115: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 116: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 117: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 118: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 119: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 120: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 121: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 122: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 123: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 124: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 125: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 126: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 127: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 128: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 129: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 130: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 131: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 132: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 133: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 134: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 135: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 136: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 137: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 138: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 139: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 140: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 141: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 142: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 143: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 144: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 145: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 146: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 147: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 148: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 149: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 150: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 151: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 152: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 153: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 154: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 155: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 156: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 157: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 158: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 159: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 160: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 161: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 162: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 163: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 164: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 165: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 166: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 167: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 168: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 169: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 170: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 171: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 172: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 173: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 174: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 175: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 176: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 177: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 178: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 179: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 180: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 181: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 182: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 183: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 184: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 185: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 186: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 187: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 188: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 189: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 190: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 191: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 192: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 193: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 194: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 195: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 196: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 197: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 198: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 199: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 200: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 201: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 202: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 203: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 204: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 205: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 206: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 207: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 208: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 209: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 210: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 211: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 212: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 213: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 214: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 215: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 216: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 217: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 218: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 219: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 220: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 221: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 222: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 223: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 224: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 225: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 226: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 227: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 228: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 229: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 230: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 231: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 232: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 233: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 234: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 235: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 236: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 237: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 238: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 239: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 240: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 241: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 242: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 243: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 244: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 245: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 246: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 247: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 248: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 249: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 250: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 251: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 252: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 253: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 254: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 255: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 256: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 257: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 258: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 259: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 260: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 261: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 262: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 263: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 264: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 265: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 266: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 267: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 268: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 269: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 270: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 271: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 272: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 273: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 274: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 275: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 276: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 277: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 278: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 279: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 280: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 281: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 282: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 283: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 284: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 285: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 286: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 287: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 288: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 289: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 290: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 291: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 292: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 293: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 294: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 295: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 296: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 297: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 298: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 299: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 300: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 301: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 302: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 303: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 304: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 305: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 306: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 307: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 308: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 309: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 310: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 311: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 312: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 313: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 314: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 315: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 316: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 317: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 318: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 319: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 320: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 321: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 322: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 323: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 324: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 325: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 326: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 327: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 328: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 329: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 330: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 331: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 332: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 333: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 334: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 48.TraduccionesValoresCodif: fila 335: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# ...
# Hoja 99.Desplegables: fila 18: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 19: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 20: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 21: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 22: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 23: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 24: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 25: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 26: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 27: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 28: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 29: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 30: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 31: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 32: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 33: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 34: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 35: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 36: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 37: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 38: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 39: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 40: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 41: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 42: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 43: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 44: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 45: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 46: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 47: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 48: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 49: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 50: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 51: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 52: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 53: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 54: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 55: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 56: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 57: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 58: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 59: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 60: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 61: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 62: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 63: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 64: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 65: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 66: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 67: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 68: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 69: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 70: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 71: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 72: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 73: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 74: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 75: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 76: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 77: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 78: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 79: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 80: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 81: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 82: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 83: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 84: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 85: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 86: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 87: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 88: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 89: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 90: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 91: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 92: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 93: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 94: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 95: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 96: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 97: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 98: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 99: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 100: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 101: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 102: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 103: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 104: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 105: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 106: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 107: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 108: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 109: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 110: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 111: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 112: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 113: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 114: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 115: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 116: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 117: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 118: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 119: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 120: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 121: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 122: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 123: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 124: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 125: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 126: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 127: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 128: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 129: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 130: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 131: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 132: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 133: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 134: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 135: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 136: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 137: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 138: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 139: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 140: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 141: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 142: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 143: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 144: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 145: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 146: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 147: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 148: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 149: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 150: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 151: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 152: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 153: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 154: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 155: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 156: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 157: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 158: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 159: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 160: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 161: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 162: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 163: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 164: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 165: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 166: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 167: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 168: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 169: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 170: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 171: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 172: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 173: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Hoja 99.Desplegables: fila 174: Ninguna celda inicia con 'UPDATE' en 'W' o 'INSERT' en 'U' para uso.
# Contador de scripts generados: 1
# Archivo 20240404-None-001-DAT-Configuracion-WFL-Inicial-v4 solo modificaciones.sql generado con éxito
# Cerramos el archivo excels\Configuracion-WFL-Inicial-v4 solo modificaciones.xlsx
# FIN

# %% [markdown]
# ##### Renombrar los excels antiguos
#
# Se renombran los excels antiguos para que no se vuelvan a procesar en caso de que el usuario no los haya borrado. O quiera tenerlos como historico.
#
# > Aún no funciona sale un error de que no se puede renombrar el archivo porque esta siendo usado por otro proceso. Se recomienda borrar los archivos excel ya procesados.

# %%
print("Se han generado los siguientes archivos SQL: ")
for nombre in nombresSQL:
    print(nombre)

# TODO: Renombrar los archivos Excel a archivo_old.xlsx Porque no me deja renombrarlos??
for archivo in archivos_excel:
    # os.remove(archivo) podria interesar mantenerlos para tener un historico
    print(f"{archivo}")
    nuevo_nombre = f"{archivo}"+"_old"
    
    try:
        # Renombrar el archivo
        os.rename(archivo, nuevo_nombre)
        print(f"Archivo renombrado: {archivo} a {nuevo_nombre}")
    except PermissionError as e:
        print(f"No se pudo renombrar el archivo {archivo}. Error: {e}")
# Out:
# Se han generado los siguientes archivos SQL:
# 20240404-None-001-DAT-Configuracion-WFL-Inicial-v4 solo modificaciones.sql
# excels\Configuracion-WFL-Inicial-v4 solo modificaciones.xlsx
# No se pudo renombrar el archivo excels\Configuracion-WFL-Inicial-v4 solo modificaciones.xlsx. Error: [WinError 32] El proceso no tiene acceso al archivo porque está siendo utilizado por otro proceso: 'excels\\Configuracion-WFL-Inicial-v4 solo modificaciones.xlsx' -> 'excels\\Configuracion-WFL-Inicial-v4 solo modificaciones.xlsx_old'
